# %% [markdown]
# # **🧠 How to Use the GPT-4o API for Vision and Text?**
# #### While GPT-4o is a new model, and the API might still be evolving, here’s a general idea of how you might interact with it:

# %% [markdown]
# ## **API for Text Model 🗒️**

# %% [markdown]
# ### `Installing necessary library`

# %%
# !pip install openai

# %% [markdown]
# ### `Importing openai library and Authentication`

# %%
import openai
openai.api_key  = "<Your API KEY>"

# %% [markdown]
# ### `For Chat Completion`

# %%
response = openai.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who won the world series in 2020?"},
    {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
    {"role": "user", "content": "Where was it played?"}
  ]
)

# %% [markdown]
# ### `Output`

# %%
print(response.choices[0].message.content)

# %% [markdown]
# ## **API for Vision Model 🖼️**

# %% [markdown]
# ### `For Chat Completion`

# %%
response = openai.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What’s in this image?"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %% [markdown]
# ### `Output`

# %%
print(response.choices[0])

# %% [markdown]
# ## You can check my,
# ### [GitHub](https://github.com/chiragjoshi12/)
# ### [Medium](https://medium.com/@chiragjoshi_12)
# ### [Kaggle](https://kaggle.com/chiragjoshi12/)
